# %% [markdown]
# ### NetworkX graph test
#
# In the code bellow there is a small test for making a co-authorship network graph of abstracts and articles using only networkX.

# %%
import networkx as nx

data = [
    {'Author Names': ['John', 'Jane'], 'Author IDs': [1, 2], 'Article Title': 'Artigo 1', 'Publication Year': 2023},
    {'Author Names': ['John', 'Robert'], 'Author IDs': [1, 3], 'Article Title': 'Artigo 2', 'Publication Year': 2023},
    {'Author Names': ['Jane', 'Alice'], 'Author IDs': [2, 4], 'Article Title': 'Artigo 3', 'Publication Year': 2022},
    {'Author Names': ['Robert', 'Alice'], 'Author IDs': [3, 4], 'Article Title': 'Artigo 4', 'Publication Year': 2022},
    {'Author Names': ['Arthur', 'Caleb'], 'Author IDs': [5, 6], 'Article Title': 'Artigo 5', 'Publication Year': 2023},
    {'Author Names': ['John', 'Caleb'], 'Author IDs': [1, 6], 'Article Title': 'Artigo 6', 'Publication Year': 2023},
    {'Author Names': ['Arthur', 'Robert'], 'Author IDs': [5, 3], 'Article Title': 'Artigo 7', 'Publication Year': 2023},
    {'Author Names': ['Sophia', 'David'], 'Author IDs': [7, 8], 'Article Title': 'Artigo 8', 'Publication Year': 2021},
    {'Author Names': ['Sophia', 'Emma'], 'Author IDs': [7, 9], 'Article Title': 'Artigo 9', 'Publication Year': 2022},
    {'Author Names': ['David', 'Emma'], 'Author IDs': [8, 9], 'Article Title': 'Artigo 10', 'Publication Year': 2022},
    {'Author Names': ['Lucas', 'Olivia'], 'Author IDs': [10, 11], 'Article Title': 'Artigo 11', 'Publication Year': 2023},
    {'Author Names': ['Mia', 'James'], 'Author IDs': [12, 13], 'Article Title': 'Artigo 12', 'Publication Year': 2023},
    {'Author Names': ['Amelia', 'William'], 'Author IDs': [14, 15], 'Article Title': 'Artigo 13', 'Publication Year': 2021},
    {'Author Names': ['James', 'Isabella'], 'Author IDs': [13, 16], 'Article Title': 'Artigo 14', 'Publication Year': 2023},
    {'Author Names': ['Amelia', 'Charlotte'], 'Author IDs': [14, 17], 'Article Title': 'Artigo 15', 'Publication Year': 2023},
    {'Author Names': ['John', 'Sophia', 'David'], 'Author IDs': [1, 7, 8], 'Article Title': 'Artigo 16', 'Publication Year': 2021},
    {'Author Names': ['Lucas', 'Mia', 'Amelia'], 'Author IDs': [10, 12, 14], 'Article Title': 'Artigo 17', 'Publication Year': 2022},
    {'Author Names': ['John', 'Emma', 'Charlotte'], 'Author IDs': [1, 9, 17], 'Article Title': 'Artigo 18', 'Publication Year': 2023},
    {'Author Names': ['Olivia', 'James', 'William'], 'Author IDs': [11, 13, 15], 'Article Title': 'Artigo 19', 'Publication Year': 2023},
    {'Author Names': ['Arthur', 'Isabella', 'Sophia'], 'Author IDs': [5, 16, 7], 'Article Title': 'Artigo 20', 'Publication Year': 2022},
    {'Author Names': ['John', 'Lucas', 'Olivia', 'Arthur'], 'Author IDs': [1, 10, 11, 5], 'Article Title': 'Artigo 21', 'Publication Year': 2022},
    {'Author Names': ['Robert', 'Alice', 'Mia'], 'Author IDs': [3, 4, 12], 'Article Title': 'Artigo 22', 'Publication Year': 2021},
    {'Author Names': ['Caleb', 'David', 'Jane', 'Sophia'], 'Author IDs': [6, 8, 2, 7], 'Article Title': 'Artigo 23', 'Publication Year': 2023},
    {'Author Names': ['Amelia', 'Charlotte', 'Alice'], 'Author IDs': [14, 17, 4], 'Article Title': 'Artigo 24', 'Publication Year': 2023},
    {'Author Names': ['Arthur', 'Olivia', 'Robert'], 'Author IDs': [5, 11, 3], 'Article Title': 'Artigo 25', 'Publication Year': 2023},
    {'Author Names': ['Emma', 'Sophia', 'Isabella'], 'Author IDs': [9, 7, 16], 'Article Title': 'Artigo 26', 'Publication Year': 2021},
    {'Author Names': ['Jane', 'Mia', 'Lucas', 'Caleb'], 'Author IDs': [2, 12, 10, 6], 'Article Title': 'Artigo 27', 'Publication Year': 2022},
    {'Author Names': ['John', 'Arthur', 'Isabella'], 'Author IDs': [1, 5, 16], 'Article Title': 'Artigo 28', 'Publication Year': 2023},
    {'Author Names': ['Robert', 'Caleb', 'William'], 'Author IDs': [3, 6, 15], 'Article Title': 'Artigo 29', 'Publication Year': 2022},
    {'Author Names': ['James', 'David', 'Amelia'], 'Author IDs': [13, 8, 14], 'Article Title': 'Artigo 30', 'Publication Year': 2022},
]

graph = nx.Graph()

for item in data:
    authors = item['Author Names']
    for i in range(len(authors)):
        for j in range(i + 1, len(authors)):
            graph.add_edge(authors[i], authors[j])

pos = nx.circular_layout(graph)

nx.draw(graph, with_labels=True, pos=pos, node_color='lightgreen')
